# %%
import pandas as pd
import numpy as np
import matplotlib as plt


df = pd.read_csv('IBRD_Statement_of_Loans_-_Latest_Available_Snapshot.csv');

# %%
df.head(1)
# Out:
#   End of Period Loan Number                   Region Country Code Country  \
# 0    12/31/2016   IBRD00010  EUROPE AND CENTRAL ASIA           FR  France
#
#           Borrower Guarantor Country Code Guarantor Loan Type   Loan Status  \
# 0  CREDIT NATIONAL                     FR    France       NPL  Fully Repaid
#
#            ...            Repaid 3rd Party Due 3rd Party Loans Held  \
# 0          ...               $249962000.00         $0.00      $0.00
#
#   First Repayment Date Last Repayment Date Agreement Signing Date  \
# 0           11/01/1952          05/01/1977             05/09/1947
#
#   Board Approval Date Effective Date (Most Recent) Closed Date (Most Recent)  \
# 0          05/09/1947                   06/09/1947                12/31/1947
#
#   Last Disbursement Date
# 0                    NaN
#
# [1 rows x 33 columns]

# %%
df.describe()
# Out:
#        Interest Rate
# count   12806.000000
# mean        5.123164
# std         2.702880
# min         0.000000
# 25%         2.340000
# 50%         5.560000
# 75%         7.250000
# max        16.790000

# %%
df['Interest Rate'].value_counts()
# Out:
# 7.25     582
# 8.50     455
# 5.59     232
# 7.43     231
# 6.03     221
# 11.60    179
# 8.25     177
# 7.00     166
# 6.00     152
# 5.50     150
# 7.90     145
# 1.91     141
# 6.50     132
# 8.20     131
# 7.50     129
# 6.18     125
# 1.76     122
# 8.00     113
# 9.60     109
# 5.75     101
# 1.81     101
# 3.80      88
# 1.67      87
# 1.85      86
# 1.75      84
# 4.85      83
# 7.45      78
# 1.47      76
# 1.87      75
# 0.00      74
#         ...
# 7.55       1
# 10.64      1
# 13.71      1
# 1.40       1
# 5.73       1
# 13.32      1
# 8.82       1
# 6.58       1
# 6.55       1
# 6.37       1
# 7.66       1
# 7.28       1
# 8.34       1
# 16.79      1
# 0.23       1
# 7.14       1
# 3.40       1
# 9.33       1
# 8.55       1
# 1.04       1
# 13.73      1
# 2.77       1
# 9.55       1
# 9.17       1
# 0.24       1
# 9.65       1
# 9.30       1
# 10.40      1
# 2.68       1
# 9.59       1
# Name: Interest Rate, Length: 897, dtype: int64

# %%
df['original_principal_amount'].hist(bins=50)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/saurabh/anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5280)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5126)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20523)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20477)()
#
# KeyError: 'original_principal_amount'
#
# During handling of the above exception, another exception occurred:
#
# ...
